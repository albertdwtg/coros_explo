# %%
data_folder = ".data"
export_name = "coros_export_20251126"
zip_file = export_name + ".zip"

# %%
import zipfile
import fitparse
from fitparse import FitParseError
import polars as pl

records = []

with zipfile.ZipFile(zip_file, 'r') as zf:
    zf.extractall(f"{data_folder}/{export_name}")
    for filename in zf.namelist():
        print(filename)
        if not filename.endswith('/'):  # Skip directories
            path = f"{data_folder}/{export_name}/{filename}"
            fitfile = fitparse.FitFile(path)
            try:
                for record in fitfile.get_messages():
                    # Parcourir toutes les données de ce message
                    # print("=========================")
                    # print(dir(record))
                    # print(record.name)
                    # print(record.as_dict())
                    if record.name == "record":
                        record_dict = {}
                        for record_data in record:
                            # Afficher le nom et la valeur de chaque donnée
                            record_dict[record_data.name] = record_data.value
                            records.append(record_dict)
                            # print(f"{record_data.name}: {record_data.value}")
            except FitParseError as e:
                pass

        # print(records)
        break

df = pl.DataFrame(records)
print(records[-1])
df.tail()
# Out:
# 457254402414116864.fit
# {'activity_type': 'running', 'cadence': None, 'distance': 2175.0, 'enhanced_speed': None, 'heart_rate': None, 'position_lat': 583759462, 'position_long': 26799880, 'speed': None, 'step_length': None, 'timestamp': datetime.datetime(2023, 12, 24, 7, 16, 55)}
# shape: (5, 10)
# ┌─────────────┬──────────┬────────────┬────────────┬───┬────────────┬───────┬────────────┬─────────┐
# │ activity_ty ┆ distance ┆ timestamp  ┆ enhanced_s ┆ … ┆ position_l ┆ speed ┆ step_lengt ┆ cadence │
# │ pe          ┆ ---      ┆ ---        ┆ peed       ┆   ┆ ong        ┆ ---   ┆ h          ┆ ---     │
# │ ---         ┆ f64      ┆ datetime[μ ┆ ---        ┆   ┆ ---        ┆ f64   ┆ ---        ┆ i64     │
# │ str         ┆          ┆ s]         ┆ f64        ┆   ┆ i64        ┆       ┆ f64        ┆         │
# ╞═════════════╪══════════╪════════════╪════════════╪═══╪════════════╪═══════╪════════════╪═════════╡
# ...
